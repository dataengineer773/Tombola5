# %%
import abc

# %%
class tombola(abc.ABC):
    def load(self, iterable):
        return bool(self.inspect())

# %%
class Fake(Tombola):
    def pick(self):
        return 13
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class Fake(Tombola):
#       2     def pick(self):
#       3         return 13
#
# NameError: name 'Tombola' is not defined
